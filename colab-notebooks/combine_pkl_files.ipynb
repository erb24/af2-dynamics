# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
import matplotlib
import os
import time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -lrth /content/drive/MyDrive/AF2_dynamics/calculated_data/
# Out:
# total 11G
# -rw------- 1 root root 5.2G Apr 16 11:07 HA_tcf_calc_raw_allmethods.pkl
# -rw------- 1 root root 661K Apr 16 11:09 RMSF_mdtraj.pkl
# -rw------- 1 root root 237M Apr 16 11:10 HA_tcf_calc_6p9a_mode_236.pkl
# -rw------- 1 root root 237M Apr 16 11:10 HA_tcf_calc_6p9a_modes_0_236.pkl
# -rw------- 1 root root  13M Apr 16 12:06 LE4PD_MD_1ebw.pkl
# -rw------- 1 root root  13M Apr 16 12:06 LE4PD_MD_6p9a.pkl
# -rw------- 1 root root  16M Apr 16 12:06 LE4PD_MD_4z4x.pkl
# -rw------- 1 root root 3.9M Apr 16 12:07 Ensemble_structures_1ebw.pkl
# -rw------- 1 root root 3.8M Apr 16 12:07 Ensemble_structures_4z4x.pkl
# -rw------- 1 root root 3.8M Apr 16 12:07 Ensemble_structures_6p9a.pkl
# -rw------- 1 root root 5.1G Jun  5 12:18 HA_tcf_calc_raw_template.pkl

# %%
# !pwd
# Out:
# /content

# %%
result = []
path = '/content/drive/MyDrive/AF2_dynamics/calculated_data/'
for d in ['HA_tcf_calc_raw_allmethods.pkl', 'HA_tcf_calc_raw_template.pkl']:
  print(d)
  with open(path + d, 'rb') as f:
      content = pickle.load(f)
  result.append(content)
with open(path + 'all_results.pkl', 'wb') as out:
    pickle.dump(result, out, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# HA_tcf_calc_raw_allmethods.pkl
# HA_tcf_calc_raw_template.pkl
